# %%
import pandas as pd
from dotenv import load_dotenv

load_dotenv("../.env")  # reads variables from a .env file and sets them in os.environ

df = pd.read_csv("../data/lugano-universita-air-quality.csv", parse_dates=["date"], skipinitialspace=True)

df.head()
# Out:
#         date  pm25  pm10    o3   no2  so2
# 0 2026-01-01  73.0  18.0  17.0  12.0  NaN
# 1 2026-01-02  62.0   9.0  19.0  10.0  NaN
# 2 2026-01-03  28.0   9.0  25.0  10.0  NaN
# 3 2026-01-04  29.0  12.0  19.0  12.0  NaN
# 4 2026-01-05  40.0  15.0  18.0  13.0  NaN

# %%
from air_quality_forecasting.configs import AirQualityForecastingServiceConfig as Config

config = Config.from_yaml("../config.yaml")
config
# Out:
# AirQualityForecastingServiceConfig(city='Lugano', street='Università della Svizzera italiana', aqicn_id='@2689', aqicn_data_path='./data/lugano-universita-air-quality.csv')

# %%
import hopsworks

project = hopsworks.login()
fs = project.get_feature_store()
# Out:
# 2026-01-30 00:58:57,534 INFO: Initializing external client
# 2026-01-30 00:58:57,534 INFO: Base URL: https://eu-west.cloud.hopsworks.ai:443
# 2026-01-30 00:58:58,662 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://eu-west.cloud.hopsworks.ai:443/p/4218
